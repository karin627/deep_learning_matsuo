# %% [markdown]
# # 第09回講義 宿題

# %% [markdown]
# ## 課題
# 今回の課題は確認クイズです．
#
# 上から回答していくとcsv提出用csv `submission_pred.csv`が作成されます．
# 提出期限までにomnicampusに提出してください．
#
# **採点は締め切り後に一回だけ行われます．**
# （**即時採点ではありません．**）

# %%
# この部分は修正しないでください
import numpy as np
import pandas as pd

NUM_EXAMPLE_QUESTIONS = 1
example = np.zeros(NUM_EXAMPLE_QUESTIONS,int)

NUM_QUESTIONS = 10
myanswer = np.zeros(NUM_QUESTIONS,int)

# %% [markdown]
# ### 回答方法
# 各$\fbox{　(　)　}$に当てはまるものとして最も適切なものを1つずつ選んでください．
#
# **例題**
#
# 「DL基礎講座」の講義では$\fbox{　(0)　}$の技術に関して基礎的なアルゴリズムについて理解し，実装することができることを目的とする．
#
# 1. 暗号化アルゴリズム
# 2. 深層学習
# 3. ブロックチェーン
# 4. ビジネスモデル
#
# 正しい回答を「深層学習」とすると、以下のように0番目に2を数字で回答します．

# %% [markdown]
# ```python
# example[0] = 2
#
# ```

# %% [markdown]
# ### 確認クイズ
# **Q1 自己回帰言語モデルの説明として，最も適切なものは次のうちどれ？**
#
# 1. ニューラルネットワークを用いて，直近のn-1個の単語のみから次の単語を予測するモデルである ．
# 2. 大規模コーパス内の単語列の出現頻度に基づいて，次の単語の確率を統計的に推定するモデルである ．
# 3. 入力された単語の文脈を考慮せず，固定の単語ベクトルを割り当てるモデルである．
# 4. ある単語の系列の生成確率を，過去の単語が与えられたときの条件付き確率の積として表現するモデルである ．
#
#
# 回答: $\fbox{　(0)　}$
#
# **Q2 サブワード単位でのトークナイゼーションの説明として最も適切なものは次のうちどれ？**
#
# 1. 必ず語彙リストを事前に用意する必要がある．
# 2. 代表的な手法にGreedy Decodingがある．
# 3. 単語単位でのトークナイゼーションよりも計算量が少ない ．
# 4. 単語をより細かい単位に分割する手法である．
#
# 回答: $\fbox{　(1)　}$
#
# **Q3 長文生成を行う際に好まれるデコード方式は次のうちどれ？**
#
# 1. random sampling
# 2. Beam Search
# 3. greedy Decoding
# 4. どれでも変わらない
#
# 回答: $\fbox{　(2)　}$
#
# **Q4 LLMの説明として<u>適切でないもの</u>は次のうちどれ？**
# 1. 事前学習によって汎用性が獲得される．
# 2. 計算資源, 学習データ量, パラメータ数の増加に比例して性能が上がる．
# 3. Transformerの中でも，Encoder-onlyモデルが主流である．
# 4. LLMは，基盤モデルの一種である．
#
# 回答: $\fbox{　(3)　}$
#
# **Q5 LLMにおける量子化の主な目的について，最も適切なものは次のうちどれ？**
#
# 1. モデルのパラメータ数を増やすこと．
# 2. 推論時のメモリ使用量を削減すること．
# 3. 訓練データ量を増やすこと．
# 4. モデルの汎化性能を向上させること．
#
# 回答: $\fbox{　(4)　}$
#
#
# **Q6 スケール則のグラフにおいて，モデルサイズが小さい（N）場合と大きい（N’’）場合の「Test Loss」の振る舞いの違いについて，最も適切に説明しているものは次のうちどれ？**
#
# 1. 小さいモデルは少ない計算資源でも速くLossが下がり，大きいモデルは計算資源を多く使ってもLossが下がりにくい．
# 2. 小さいモデルはすぐにLossが下がるが，大きいモデルは初期のLoss低下は遅いが学習を続けると最終的により良いパフォーマンスを達成する．
# 3. 大きいモデルの方が，常に低いLoss値を達成できる．
# 4. どちらのモデルサイズでも，計算資源を増やせばLossは際限なく下がり続ける．
#
# 回答: $\fbox{　(5)　}$
#
# **Q7 CoTが，算数の文章題など従来難しいとされていた推論タスクで性能を大幅に向上させた要因として，最も適切なものは次のうちどれ？**
#
# 1. 単語列の生起確率を最大化するデコード方式を採用したため．
# 2. Few-Shotの事例の際に思考過程を入れることで，新しい質問についても思考過程を明示してくれるようになったため．
# 3. プロンプトの長さを極端に短縮したため．
# 4. モデルサイズを劇的に縮小したため．
#
# 回答: $\fbox{　(6)　}$
#
# **Q8 LLMの推論能力を高める研究の一つとして紹介されている「Self-consistency」の主なアプローチについて説明しているものは次のうちどれ？**
#
# 1. LLMに複数の推論を行わせ，多数決で答えを決定する．
# 2. LLMの出力をLLM自身が繰り返し修正する．
# 3. 思考過程を木構造で探索し，ノードの評価もLMで行う．
# 4. 入力に思考過程を入れるプロンプトを使用する．
#
# 回答: $\fbox{　(7)　}$
#
# **Q9LLMの計算量に関する記述として，最も適切なものは次のうちどれ？**
#
# 1. FLOPsもFLOPSも，どちらも同じ意味で使われる．
# 2. FLOPsは単位時間あたりの演算回数を表す．
# 3. FLOPSはスケール則の横軸に用いられる．
# 4. FLOPsは必要な合計演算回数を表す．
#
# 回答: $\fbox{　(8)　}$
#
# **Q10 LLMに対する攻撃の内，LLM の安全性・倫理ガイドラインを回避して不適切な出力を引き出す手法は次のうちどれ？**
#
# 1. Prompt Injection
# 2. Data Poisoning
# 3. Jailbreak
# 4. ToT
#
# 回答: $\fbox{　(9)　}$

# %%
myanswer[0] =
myanswer[1] =
myanswer[2] =
myanswer[3] =
myanswer[4] =
myanswer[5] =
myanswer[6] =
myanswer[7] =
myanswer[8] =
myanswer[9] =

# %%
# omnicampusへ提出するcsvファイルが作成されます．
if not np.any(myanswer==0):
    submission = pd.Series(myanswer, name='label')
    submission.to_csv('/content/submission_pred.csv', header=True, index_label='id')
else:
    print('Error: please answer all of the questions')

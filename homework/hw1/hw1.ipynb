# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-u5etiivr
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-u5etiivr
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...

# %%
import torch
import clip
from PIL import Image
import numpy as np

# %%
def clip_image_classifier(image_path, texts):
  device = "cuda" if torch.cuda.is_available() else "cpu"
  model, preprocess = clip.load("ViT-B/32", device=device)

  image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
  text_tokens = clip.tokenize(texts).to(device)

  with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text_tokens)

    logits_per_image, logits_per_text = model(image, text_tokens)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy().flatten()

  print("類似度スコア：")
  for t, p in zip(texts, probs):
    print(f" - '{t}': {p:.4f}")

# %%
texts = [
    "a dog",
    "a hat",
    "flowers",
    "grass"
]
image_path = "dog_hat.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a dog': 0.3872
#  - 'a hat': 0.6094
#  - 'flowers': 0.0008
#  - 'grass': 0.0026

# %%
texts = [
    "a fluffy animal with a headgear",
    "a cat in a room",
]
image_path = "dog_hat.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a fluffy animal with a headgear': 0.9956
#  - 'a cat in a room': 0.0046

# %%
texts = [
    "a dog wearing a hat",
    "a fluffy animal with a headgear",
]
image_path = "dog_hat.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a dog wearing a hat': 0.9995
#  - 'a fluffy animal with a headgear': 0.0003

# %%
texts = [
    "a man",
    "a woman",
]
image_path = "man_flower.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a man': 0.6724
#  - 'a woman': 0.3276

# %%
texts = [
    "a man",
    "a woman",
]
image_path = "man.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a man': 0.9932
#  - 'a woman': 0.0069

# %%
texts = [
    "a man wearing a dress and buying flowers",
    "a woman wearing a dress and buying flowers",
    "a person in a dress buying flowers"
]
image_path = "man_flower.jpg"
clip_image_classifier(image_path, texts)
# Out:
# 類似度スコア：
#  - 'a man wearing a dress and buying flowers': 0.7002
#  - 'a woman wearing a dress and buying flowers': 0.1057
#  - 'a person in a dress buying flowers': 0.1943
